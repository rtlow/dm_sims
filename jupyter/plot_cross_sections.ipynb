# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import glob

# %%
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
matplotlib.rcParams['font.size']=14

# %%
fpath = '/home/ryan/projects/Medvedev/dm_sims/cross_sections/sigma1_power0/'

no_files = len(glob.glob(fpath + "sidm_cross_reaction_*"))

files = [ fpath + "sidm_cross_reaction_{}.txt".format(i) for i in range(no_files) ]

# %%
vs = []
cs = []

for i in range(no_files):
    data = np.loadtxt(files[i])
    vs.append(data[:, 0])
    cs.append(data[:, 1])

# %%
fig, ax = plt.subplots(figsize=[12,12])

for i in range(no_files):
    
    ax.plot(vs[i], cs[i], label='Reaction {}'.format(i))

ax.set_yscale('log')
ax.set_xscale('log')
ax.legend()
ax.set_xlabel('$ \log$ v')
ax.set_ylabel('$ \log $ $\sigma$ / m')
ax.set_title("Cross sections for $\sigma_0 = 1$ and (0,0) power law")
ax.grid(True, which="both", ls="-")
plt.savefig('cross_section_1.png')
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#
# /home/ryan/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
