# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import pynbody
from pynbody.analysis import profile

import os
import glob

from tqdm.notebook import tqdm

import sys
sys.path.append('../../py/')

from cosmoSim import cosmoSim

# %%
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)
matplotlib.rcParams['font.size']=12

# %%
data_path = "/home/ryan/Data/"
base_path="../../data_prods/"

out_path = '../../plots/movie_811/'


try:
    os.mkdir(out_path)
except:
    print(f'{out_path} already exists!')
# Out:
# ../../plots/movie_811/ already exists!

# %%
z_max = 5

with open('../../file_parts/ExpansionList_128', 'r') as f:
    lines = f.read().split('\n')

a = np.array([ float(l.strip().split(' ')[0]) for l in lines if l])

zs = 1/a - 1

zs = zs[ zs < z_max ]

# %%
CDM_RUNS = [
    'run_CDM_811_HY_dir_0'
]

tcDM_search = '../../data_prods/run_2cDM_811_HY_power00*Vkick*'

tcDM_RUNS = [ os.path.basename(x) for x in sorted(glob.glob(tcDM_search)) ]

# %%
Vkicks = [ cosmoSim(x).Vkick for x in tcDM_RUNS ]

c_norm = matplotlib.colors.LogNorm(vmin=np.amin(Vkicks), vmax=np.amax(Vkicks))
c_map = matplotlib.cm.plasma

s_map = matplotlib.cm.ScalarMappable(cmap=c_map, norm=c_norm)

# %%
soft_eff = 100000 / 2**11 / 39

# %%
def calculate_profile(run_name, redshift):
    
    run = cosmoSim(run_name, base_path=base_path)
    idx = run.redshift_to_index(redshift)
    # load the file
    # print(data_path + f'/{run_name}/snap_{idx:03}.hdf5')
    f = pynbody.load(data_path + f'/{run_name}/snap_{idx:03}.hdf5')
    h = f.halos(subhalos=True)

    f.physical_units()
    
    # only care about most massive halo for now
    pynbody.analysis.faceon(h[0])
    p_3d = profile.Profile(h[0], rmin = '.05 kpc', rmax = '100 kpc', ndim = 3)
    return p_3d['rbins'].in_units('kpc'), p_3d['density'].in_units('Msol kpc^-3')

# %%
for redshift in tqdm(zs):

    fig, ax = plt.subplots(1, 1, figsize=[12, 12])

    runf = cosmoSim(CDM_RUNS[0])
    idx = runf.redshift_to_index(redshift)

    # diagnostic only
    if idx < 63:
        continue

    # plot 2cDM runs
    for rn in tcDM_RUNS:
        run = cosmoSim(rn)

        # print(idx, rn)
        try:
            rbins, masses = calculate_profile(rn, redshift)
        except KeyError:
            print(f'Error with run {rn} for profile {idx}')
            print('Skipping...')
            continue

        plt.plot(rbins, masses, color=s_map.to_rgba(run.Vkick))

    fig.colorbar(s_map, label='$V_{kick}$ [km s$^{-1}$]', ax=ax)

    # plot CDM run
    for rn in CDM_RUNS:

        rbins, masses = calculate_profile(rn, redshift)

        plt.plot(rbins, masses, color='k', linestyle=(5, (10, 3)))

    # plot formatting
    ax.set_xlabel('$r$ [kpc]')
    ax.set_ylabel(r'$\rho$ [M$_{\odot}$ kpc$^{-3}$]')

    ax.vlines(soft_eff, 10**2, 10**50, colors='k', linestyles='dashed')
    ax.vlines(2.8*soft_eff, 10**2, 10**50, colors='k', linestyles='dashdot')

    ax.set_ylim([10**3, 10**10])

    ax.plot([],[], label=f'z = {redshift:.3f}', alpha=0)

    ax.set_yscale("log")
    ax.set_xscale("log")
    ax.grid(True, which="both", ls="-")
    ax.set_box_aspect(aspect=1)
    ax.legend()
    plt.title('Density Profile 811 HY')

    fname = f'density_811_HY_{idx:03}.png'
    plt.savefig(out_path + fname)

    plt.close(fig)
# Out:
#   0%|          | 0/83 [00:00<?, ?it/s]
# /home/ryan/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/snapshot/gadgethdf.py:761: UserWarning: Masses are either stored in the header or have another dataset name; assuming the cosmological factor h**-1
#   warnings.warn("Masses are either stored in the header or have another dataset name; assuming the cosmological factor %s" % units.h**-1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 10
#       7     run = cosmoSim(rn)
#       8     idx = run.redshift_to_index(redshift)
# ---> 10     rbins, masses = calculate_profile(rn, redshift)
#      12     plt.plot(rbins, masses, color=s_map.to_rgba(run.Vkick))
#      14 fig.colorbar(s_map, label='$V_{kick}$ [km s$^{-1}$]', ax=ax)
#
# Cell In[8], line 15, in calculate_profile(run_name, redshift)
#      13 pynbody.analysis.faceon(h[0])
#      14 p_3d = profile.Profile(h[0], rmin = '.05 kpc', rmax = '100 kpc', ndim = 3)
# ---> 15 return p_3d['rbins'].in_units('kpc'), p_3d['density'].in_units('Msol kpc^-3')
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:365, in Profile.__getitem__(self, name)
#     363     return self._properties[name]
#     364 else:
# --> 365     return self._get_profile(name)
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:277, in Profile._get_profile(self, name)
#     275 elif x[0] in Profile._profile_registry:
#     276     args = x[1:]
# --> 277     self._profiles[name] = Profile._profile_registry[x[0]](self, *args)
#     279     try:
#     280         self._profiles[name].sim = self.sim
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:572, in density(pro)
#     567 @Profile.profile_property
#     568 def density(pro):
#     569     """
#     570     Generate a radial density profile for the current type of profile
#     571     """
# --> 572     return pro['mass'] / pro._binsize
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:365, in Profile.__getitem__(self, name)
#     363     return self._properties[name]
#     364 else:
# --> 365     return self._get_profile(name)
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:277, in Profile._get_profile(self, name)
#     275 elif x[0] in Profile._profile_registry:
#     276     args = x[1:]
# --> 277     self._profiles[name] = Profile._profile_registry[x[0]](self, *args)
#     279     try:
#     280         self._profiles[name].sim = self.sim
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:563, in mass(pro)
#     561 @Profile.profile_property
#     562 def mass(pro):
# --> 563     return weight_fn(pro, 'mass')
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/analysis/profile.py:548, in weight_fn(pro, weight_by)
#     546 if weight_by is None:
#     547     weight_by = pro._weight_by
# --> 548 mass = array.SimArray(np.zeros(pro.nbins), pro.sim[weight_by].units)
#     550 with pro.sim.immediate_mode:
#     551     pmass = pro.sim[weight_by].view(np.ndarray)
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/snapshot/simsnap.py:252, in SimSnap.__getitem__(self, i)
#     249 from . import subsnap
#     251 if isinstance(i, str):
# --> 252     return self._get_array_with_lazy_actions(i)
#     253 elif isinstance(i, slice):
#     254     return subsnap.SubSnap(self, i)
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/snapshot/simsnap.py:351, in SimSnap._get_array_with_lazy_actions(self, name)
#     344         self._dependency_tracker.touching(nd_name)
#     346 elif not self.lazy_off:
#     347     # The array is not currently in memory at the level we need it, and there is a possibility
#     348     # of getting it into memory using lazy derivation or loading. First, if there is a family level
#     349     # array by the same name, dispose of it. (Note if this is being called on a FamilySubSnap, the below
#     350     # has no effect, and anyway we wouldn't reach this point in the code if the family array were available.)
# --> 351     self.__resolve_obscuring_family_array(name)
#     353     # Now, we'll try to load the array...
#     354     if not self.lazy_load_off:
#     355         # Note that we don't want this to be inside _dependency_tracker.calculating(name), because there is a
#     356         # small possibility the load will be mapped into a derivation by the loader class. Specifically this
#     357         # happens in ramses snapshots for the mass array (which is derived from the density array for gas cells).
#
# File ~/miniconda3/envs/work/lib/python3.12/site-packages/pynbody/snapshot/simsnap.py:400, in SimSnap.__resolve_obscuring_family_array(self, name)
#     398 if name in self.family_keys():
#     399     in_fam, out_fam = self.__get_included_and_excluded_families_for_array(name)
# --> 400     raise KeyError("""{!r} is a family-level array for {}. To use it over the whole simulation you need either to delete it first, or create it separately for {}.""".format(
#     401         name, in_fam, out_fam))
#
# KeyError: "'mass' is a family-level array for [<Family gas>, <Family dm>, <Family star>]. To use it over the whole simulation you need either to delete it first, or create it separately for []."
