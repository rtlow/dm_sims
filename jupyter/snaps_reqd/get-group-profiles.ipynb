# %%
import os
from pathlib import Path
import json
import glob
import h5py
import numpy as np
from tqdm.notebook import tqdm

# %%
outdir = '../../data_prods/'
data_dir = '/home/ryan/Data'

subdir_list = [os.path.join(data_dir, o) for o in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir,o))]

print(subdir_list)
# Out:
# ['/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_2', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_7_Vkick119.90', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma0.1', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma5.0_dir_9', '/home/ryan/Data/run_2cDM_L3N512_HY_power00_sigma1', '/home/ryan/Data/run_2cDM_L3N256_HY_power00_sigma0.1', '/home/ryan/Data/run_2cDM_L25N256_DM_power00_sigma1_dir_4_Vkick55.65', '/home/ryan/Data/run_CDM_L5N256_DM', '/home/ryan/Data/run_2cDM_L3N256_HY_power00_sigma1_dir_9', '/home/ryan/Data/run_SIDM_L3N256_DM_power0_sigma1', '/home/ryan/Data/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_5', '/home/ryan/Data/run_2cDM_L25N256_DM_power00_sigma1_dir_7_Vkick119.90', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1', '/home/ryan/Data/lost+found', '/home/ryan/Data/run_2cDM_L3N256_HY_power00_sigma1_dir_5', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_3', '/home/ryan/Data/run_2cDM_L3N256_HY_powerm2m2_sigma10', '/home/ryan/Data/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_8', '/home/ryan/Data/run_CDM_L3N256_DM_dir_7', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_8', '/home/ryan/Data/run_CDM_L5N256_HY', '/home/ryan/Data/run_2cDM_811_HY_power00_sigma1_dir_4_Vkick55.65', '/home/ryan/Data/run_2cDM_L25N256_DM_power00_sigma1_dir_2_Vkick33.36', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma2.32_dir_6', '/home/ryan/Data/run_2cDM_L3N128_HY_power00_sigma0.1_10e-7', '/home/ryan/Data/run_2cDM_L3N256_HY_power00_sigma1_dir_1', '/home/ryan/Data/run_2cDM_710_DM_power00_sigma1_dir_5_Vkick71.88', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_5_Vkick71.88', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_4_Vkick55.65', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1_Vkick25.83', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma0.1', '/home/ryan/Data/run_2cDM_L3N128_HY_power00_sigma0.1_var4', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_4', '/home/ryan/Data/run_CDM_710_HY', '/home/ryan/Data/run_2cDM_710_HY_powerm2m2_sigma1', '/home/ryan/Data/run_CDM_811_HY_dir_0', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_1', '/home/ryan/Data/run_CDM_L3N128_HY', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma3.0_dir_7', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_7_Vkick119.90', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_6', '/home/ryan/Data/run_2cDM_L3N128_HY_power00_sigma0.1_var2', '/home/ryan/Data/run_2cDM_710_DM_power00_sigma1_dir_3_Vkick43.09', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_0', '/home/ryan/Data/run_2cDM_811_HY_power00_sigma1_dir_1_Vkick25.83', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_4_Vkick55.65', '/home/ryan/Data/run_CDM_L3N256_HY_dir_0', '/home/ryan/Data/run_SIDM_L3N256_HY_power0_sigma1', '/home/ryan/Data/run_CDM_L3N256_DM_dir_9', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma10', '/home/ryan/Data/run_CDM_L3N256_HY_dir_9', '/home/ryan/Data/run_2cDM_L3N128_DM_power00_sigma0.1', '/home/ryan/Data/run_2cDM_L10N256_DM_power00_sigma1', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_0', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3_Vkick43.09', '/home/ryan/Data/run_CDM_L3N256_DM', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_2_Vkick33.36', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_0_Vkick20.00', '/home/ryan/Data/run_2cDM_811_DM_power00_sigma1_dir_8_Vkick154.85', '/home/ryan/Data/run_2cDM_L10N256_HY_power00_sigma1', '/home/ryan/Data/run_CDM_L3N256_HY_dir_5', '/home/ryan/Data/run_2cDM_L25N256_DM_power00_sigma1_dir_6_Vkick92.83', '/home/ryan/Data/run_CDM_L3N256_HY_dir_7', '/home/ryan/Data/run_2cDM_L3N128_HY_power00_sigma0.1_var5', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3', '/home/ryan/Data/run_2cDM_710_DM_power00_sigma1_dir_1_Vkick25.83', '/home/ryan/Data/run_2cDM_L3N256_DM_power00_sigma1_dir_2', '/home/ryan/Data/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_9_Vkick200.00', '/home/ryan/Data/run_2cDM_710_DM_power00_sigma1_dir_9_Vkick200.00', '/hom ...

# %%
def make_CDF(data, nbins=1000):
    bins = np.geomspace(np.amin(data), np.amax(data), num=nbins)
    counts = np.array([ (data > b).sum() for b in bins ])
    
    return bins, counts

def get_profiles(f, nbins=1000):

    Subhalo=f.get('Group')
    
    # it's OK if it errors out here
    # if GroupMass isn't present, then there's no FoF Groups!
    SubhaloMass=np.array(Subhalo['GroupMass'])
    SubhaloMassType=np.array(Subhalo['GroupMassType'])

    SubhaloMass=10**10*SubhaloMass #converting to solar masses
    SubhaloMassType=10**10*SubhaloMassType #converting to solar masses

    SubhaloN = Subhalo['GroupLen'][()]
    enough = SubhaloN > 0

    smass = SubhaloMass[enough]
    smasstype = SubhaloMassType[enough]


    if len(smass) > 0:
        Mass_Bins, N_M = make_CDF(smass, nbins=nbins)
    else:
        Mass_Bins = N_M = np.zeros(1, dtype=np.uint8)

    
    mbins_type = []
    n_m_type = []

    for i in range(smasstype.shape[1]):
        masstype = smasstype[:,i]
        nonzero = masstype[ masstype != 0 ]

        if len(nonzero) > 0:
            mbins, N_M_type = make_CDF(nonzero, nbins=nbins)
        else:
            mbins = N_M_type = np.zeros(1, dtype=np.uint8)
        
        mbins_type.append(mbins)
        n_m_type.append(N_M_type)
    
    by_mass = smasstype[:,0] + smasstype[:,4]
    nonzero = by_mass[ by_mass != 0 ]
    if len(nonzero) > 0:
        mbins_by, N_M_by = make_CDF(nonzero, nbins=nbins)
    else:
        mbins_by = N_M_by = np.zeros(1, dtype=np.uint8)

    # sets the minimum number of particles for the cutoff
    enough = SubhaloN > 100

    smass = SubhaloMass[enough]
    
    cutoffs = []
    if len(smass > 0):
        cutoffs.append(np.amin(smass))  
        cutoffs += [ np.amin(smasstype[:,i]) for i in range(smasstype.shape[1]) ]
    else:
        cutoffs.append(-1)
        cutoffs.append(-1)   
        cutoffs += [ -1 for i in range(smasstype.shape[1]) ]

    return (Mass_Bins, N_M), (mbins_type, n_m_type), (mbins_by, N_M_by), cutoffs

# %%
for subdir in tqdm(subdir_list):

    #run name is just folder name
    run_name = subdir.split('/')[-1]

    #reject folders that aren't runs
    if 'run' not in run_name:
        continue

    fpath = os.path.join(outdir, run_name)
    try:
        os.mkdir(fpath)
    except:
        print(f'{fpath} already exists!')
    print("Working on ", run_name)

    # read info from snapshots/fof
    snaps = sorted(glob.glob(subdir + '/snap*'))
    fofs = sorted(glob.glob(subdir + '/fof*'))

    if len(snaps) == 0:
        print(f'No snapshots for run {run_name}...')
        continue

    for fof in fofs:
        i = int(Path(fof).stem.split('_')[-1])
        with h5py.File(fof, 'r') as f:
            try:
                
                (mbins, mcount), (mbins_type, mcount_type), (mbins_by, mcount_by), cutoffs = get_profiles(f)
                tname = os.path.join(fpath, "group_mass_profile_{}.txt".format(i))
                np.savetxt(tname, (mbins, mcount))

                for j in range(len(mbins_type)):
                    tname = os.path.join(fpath, f"group_part_type_{j}_mass_profile_{i}.txt")
                    np.savetxt(tname, (mbins_type[j], mcount_type[j]))
                
                tname = os.path.join(fpath, "group_by_mass_profile_{}.txt".format(i))
                np.savetxt(tname, (mbins_by, mcount_by))

                tname = os.path.join(fpath, "group_profile_cutoffs_{}.txt".format(i))
                np.savetxt(tname, cutoffs)

            except KeyError as e:
                print(e)
                continue
# Out:
#   0%|          | 0/204 [00:00<?, ?it/s]
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_2 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_2
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma0.1 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma0.1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma5.0_dir_9 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma5.0_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N512_HY_power00_sigma1 already exists!
# Working on  run_2cDM_L3N512_HY_power00_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma0.1 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma0.1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L5N256_DM already exists!
# Working on  run_CDM_L5N256_DM
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma1_dir_9 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma1_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_SIDM_L3N256_DM_power0_sigma1 already exists!
# Working on  run_SIDM_L3N256_DM_power0_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_5 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_5
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma1_dir_5 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma1_dir_5
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_3 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma10 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma10
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_8 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_8
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_DM_dir_7 already exists!
# Working on  run_CDM_L3N256_DM_dir_7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_8 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_8
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L5N256_HY already exists!
# Working on  run_CDM_L5N256_HY
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_HY_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_811_HY_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_2_Vkick33.36 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_2_Vkick33.36
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma2.32_dir_6 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma2.32_dir_6
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1_10e-7 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1_10e-7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma1_dir_1 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma1_dir_1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_5_Vkick71.88 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_5_Vkick71.88
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_5_Vkick71.88 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_5_Vkick71.88
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1_Vkick25.83 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_1_Vkick25.83
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma0.1 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma0.1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1_var4 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1_var4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_4 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_710_HY already exists!
# Working on  run_CDM_710_HY
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_HY_powerm2m2_sigma1 already exists!
# Working on  run_2cDM_710_HY_powerm2m2_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_811_HY_dir_0 already exists!
# Working on  run_CDM_811_HY_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_1 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N128_HY already exists!
# Working on  run_CDM_L3N128_HY
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma3.0_dir_7 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma3.0_dir_7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_6 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_6
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1_var2 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1_var2
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_3_Vkick43.09 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_3_Vkick43.09
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_0 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_HY_power00_sigma1_dir_1_Vkick25.83 already exists!
# Working on  run_2cDM_811_HY_power00_sigma1_dir_1_Vkick25.83
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_0 already exists!
# Working on  run_CDM_L3N256_HY_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_SIDM_L3N256_HY_power0_sigma1 already exists!
# Working on  run_SIDM_L3N256_HY_power0_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_DM_dir_9 already exists!
# Working on  run_CDM_L3N256_DM_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma10 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma10
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_9 already exists!
# Working on  run_CDM_L3N256_HY_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_DM_power00_sigma0.1 already exists!
# Working on  run_2cDM_L3N128_DM_power00_sigma0.1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L10N256_DM_power00_sigma1 already exists!
# Working on  run_2cDM_L10N256_DM_power00_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_0 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3_Vkick43.09 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3_Vkick43.09
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_DM already exists!
# Working on  run_CDM_L3N256_DM
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_2_Vkick33.36 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_2_Vkick33.36
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_0_Vkick20.00 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_0_Vkick20.00
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_811_DM_power00_sigma1_dir_8_Vkick154.85 already exists!
# Working on  run_2cDM_811_DM_power00_sigma1_dir_8_Vkick154.85
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L10N256_HY_power00_sigma1 already exists!
# Working on  run_2cDM_L10N256_HY_power00_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_5 already exists!
# Working on  run_CDM_L3N256_HY_dir_5
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_6_Vkick92.83 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_6_Vkick92.83
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_7 already exists!
# Working on  run_CDM_L3N256_HY_dir_7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1_var5 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1_var5
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_1_Vkick25.83 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_1_Vkick25.83
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_2 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_2
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_9_Vkick200.00 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_9_Vkick200.00
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_9_Vkick200.00 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_9_Vkick200.00
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_8_Vkick154.85 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_8_Vkick154.85
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_1_Vkick25.83 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_1_Vkick25.83
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L10N256_DM already exists!
# Working on  run_CDM_L10N256_DM
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N128_DM already exists!
# Working on  run_CDM_L3N128_DM
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma3.87_dir_8 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma3.87_dir_8
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_3_Vkick43.09 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_3_Vkick43.09
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_HY_power00_sigma1_dir_5_Vkick71.88 already exists!
# Working on  run_2cDM_710_HY_power00_sigma1_dir_5_Vkick71.88
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ...
# Working on  run_CDM_L3N256_DM_dir_4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_DM_dir_0 already exists!
# Working on  run_CDM_L3N256_DM_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY already exists!
# Working on  run_CDM_L3N256_HY
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_3 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1.08_dir_3 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1.08_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_1 already exists!
# Working on  run_CDM_L3N256_HY_dir_1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N128_HY_var4 already exists!
# Working on  run_CDM_L3N128_HY_var4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma1_dir_2 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma1_dir_2
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_HY_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_710_HY_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_6 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_6
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L25N256_DM_power00_sigma1_dir_9_Vkick200.00 already exists!
# Working on  run_2cDM_L25N256_DM_power00_sigma1_dir_9_Vkick200.00
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma100 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma100
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_5_Vkick71.88 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_5_Vkick71.88
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_710_HY_power00_sigma1_dir_7_Vkick119.90 already exists!
# Working on  run_2cDM_710_HY_power00_sigma1_dir_7_Vkick119.90
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_9 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_710_DM already exists!
# Working on  run_CDM_710_DM
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1.08_dir_3 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1.08_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma5.0_dir_9 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma5.0_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_7 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_4 already exists!
# Working on  run_CDM_L3N256_HY_dir_4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N128_HY_power00_sigma0.1_var6 already exists!
# Working on  run_2cDM_L3N128_HY_power00_sigma0.1_var6
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_4 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L10N256_HY already exists!
# Working on  run_CDM_L10N256_HY
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma0.646_dir_1 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma0.646_dir_1
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma0.5_dir_0 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma0.5_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N512_HY already exists!
# Working on  run_CDM_L3N512_HY
# ../../data_prods/run_2cDM_710_DM_power00_sigma1_dir_4_Vkick55.65 already exists!
# Working on  run_2cDM_710_DM_power00_sigma1_dir_4_Vkick55.65
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_3 already exists!
# Working on  run_CDM_L3N256_HY_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_0 already exists!
# Working on  run_2cDM_L3N256_HY_powerm2m2_sigma1_dir_0
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1.39_dir_4 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1.39_dir_4
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_DM_dir_3 already exists!
# Working on  run_CDM_L3N256_DM_dir_3
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_CDM_L3N256_HY_dir_2 already exists!
# Working on  run_CDM_L3N256_HY_dir_2
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_HY_power00_sigma1_dir_7 already exists!
# Working on  run_2cDM_L3N256_HY_power00_sigma1_dir_7
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_power00_sigma1_dir_9 already exists!
# Working on  run_2cDM_L3N256_DM_power00_sigma1_dir_9
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
# ../../data_prods/run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_0_Vkick20.00 already exists!
# Working on  run_2cDM_L3N256_DM_powerm2m2_sigma1_dir_0_Vkick20.00
# "Unable to synchronously open object (object 'GroupMass' doesn't exist)"
