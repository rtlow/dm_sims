# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import h5py

# %%
matplotlib.rc('xtick', labelsize=28)
matplotlib.rc('ytick', labelsize=28)
matplotlib.rcParams['font.size']=28

# %%
CDM_i_1 = tcDM_i_1 = CDM_i_2 = tcDM_i_2 = 4



snap_CDM_1 = h5py.File('/home/ryan/Data/Data0/snaps/run_CDM_L3N128/snap_00{}.hdf5'.format(CDM_i_1), 'r')
#snap_2cDM_1 = h5py.File('/home/ryan/Data/Data1/run_2cDM_L3N512_DM_power00_sigma1/snap_00{}.hdf5'.format(tcDM_i_1), 'r')
Redshift_CDM_1 ="{:.2f}".format(snap_CDM_1['Header'].attrs['Redshift'])
#Redshift_2cDM_1 = "{:.2f}".format(snap_2cDM_1['Header'].attrs['Redshift'])



"""snap_CDM_2 = h5py.File('/home/ryan/Data/Data2/run_CDM_L3N512/snap_00{}.hdf5'.format(CDM_i_2), 'r')
snap_2cDM_2 = h5py.File('/home/ryan/Data/Data2/run_2cDM_L3N512_power00_sigma1/snap_00{}.hdf5'.format(tcDM_i_2), 'r')
Redshift_CDM_2 ="{:.2f}".format(snap_CDM_2['Header'].attrs['Redshift'])
Redshift_2cDM_2 = "{:.2f}".format(snap_2cDM_2['Header'].attrs['Redshift'])
"""
fpath = '/home/ryan/Downloads/plots_L3N512/'
#fpath = '/home/ryan/Downloads/'
pkpath_1 = '/home/ryan/genPK/run_L3N512_DM/'
pkpath_2 = '/home/ryan/genPK/run_L3N512/'

lpkpath_1 = '/home/ryan/genPK/run_L3N128_DM/'
lpkpath_2 = '/home/ryan/genPK/run_L3N128_sigma1/'

#print(Redshift_CDM_1)
#print(Redshift_2cDM_1)
print(Redshift_CDM_2)
print(Redshift_2cDM_2)
#(Redshift_CDM_1 == Redshift_2cDM_1) and (Redshift_CDM_1 == Redshift_2cDM_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7cc62eb20968> in <module>
#      25 #print(Redshift_CDM_1)
#      26 #print(Redshift_2cDM_1)
# ---> 27 print(Redshift_CDM_2)
#      28 print(Redshift_2cDM_2)
#      29 #(Redshift_CDM_1 == Redshift_2cDM_1) and (Redshift_CDM_1 == Redshift_2cDM_2)
#
# NameError: name 'Redshift_CDM_2' is not defined

# %%
def calculate_fourier_conversion(Boxsize):
    '''
    Takes the Boxsize in kpc and produces the conversion factors
    from Fourier units to physical units. For use with genPK output.
    '''
    Boxsize = Boxsize / 1000 # convert to Mpc

    k_conv = 2*np.pi / Boxsize
    p_conv = (Boxsize / (2 * np.pi))**3
    
    return k_conv, p_conv

# %%
Boxsize_2 = int((snap_CDM_2['Header'].attrs['BoxSize'])) # in kpc
Boxsize_1 = int((snap_CDM_1['Header'].attrs['BoxSize'])) # in kpc

k_conv_1, p_conv_1 = calculate_fourier_conversion(Boxsize_1)
k_conv_2, p_conv_2 = calculate_fourier_conversion(Boxsize_2)

# %%
def get_genPK_data(fpath, k_conv, p_conv):
    
    genPK = np.loadtxt(fpath)
    
    bins = genPK[:, 0]
    pk = genPK[:, 1]
    
    dk = pk * (2 * np.pi)**3 * (4 * np.pi) * bins**3
    
    bins = genPK[:, 0] * k_conv
    
    pk = genPK[:, 1] * p_conv
    
    return bins, pk, dk

# %%
# get DM data for both

cdm_str = 'PK-DM-snap_00{}_CDM.hdf5'
tcdm_str = 'PK-DM-snap_00{}_2cDM.hdf5'

"""bins_cdm_1, pk_cdm_1, dk_cdm_1 = get_genPK_data(pkpath_1 + cdm_str.format(CDM_i_1),\
                                                k_conv_1, p_conv_1)
bins_2cdm_1, pk_2cdm_1, dk_2cdm_1 = get_genPK_data(pkpath_1 + tcdm_str.format(tcDM_i_1),\
                                                k_conv_1, p_conv_1)
bins_cdm_2, pk_cdm_2, dk_cdm_2 = get_genPK_data(pkpath_2 + cdm_str.format(CDM_i_2),\
                                                k_conv_2, p_conv_2)
bins_2cdm_2, pk_2cdm_2, dk_2cdm_2 = get_genPK_data(pkpath_2 + tcdm_str.format(tcDM_i_2),\
                                                k_conv_2, p_conv_2)
"""
lbins_cdm_1, lpk_cdm_1, ldk_cdm_1 = get_genPK_data(lpkpath_1 + cdm_str.format(CDM_i_1),\
                                                k_conv_1, p_conv_1)
lbins_2cdm_1, lpk_2cdm_1, ldk_2cdm_1 = get_genPK_data(lpkpath_1 + tcdm_str.format(tcDM_i_1),\
                                                k_conv_1, p_conv_1)
lbins_cdm_2, lpk_cdm_2, ldk_cdm_2 = get_genPK_data(lpkpath_2 + cdm_str.format(CDM_i_2),\
                                                k_conv_2, p_conv_2)
lbins_2cdm_2, lpk_2cdm_2, ldk_2cdm_2 = get_genPK_data(lpkpath_2 + tcdm_str.format(tcDM_i_2),\
                                                k_conv_2, p_conv_2)

# %%
def wnumber2wlength(k):
    return 1/k
def wlength2wnumber(l):
    return 1/l

# %%
fig, ax = plt.subplots(figsize=[12,12])
ax.plot(bins_cdm_1,pk_cdm_1, label='CDM DM', color='g')
ax.plot(bins_2cdm_1,pk_2cdm_1, '--',label='2cDM DM', color='k')
ax.plot(bins_cdm_2,pk_cdm_2, label='CDM Hydro', color='r')
ax.plot(bins_2cdm_2,pk_2cdm_2, '--',label='2cDM Hydro', color='b')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$P(k)$')
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('DM Power Spectrum z = {}'.format(Redshift_CDM_2))
plt.legend()
plt.grid(True, which="both", ls="-")
fname = 'DM_Power_Spectrum_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=[24,18], gridspec_kw={'height_ratios': [3, 1]})
ax0.plot(bins_cdm_1,dk_cdm_1, label='CDM DM', color='g')
ax0.plot(bins_2cdm_1,dk_2cdm_1, '--',label='2cDM DM', color='k')
ax0.plot(bins_cdm_2,dk_cdm_2, label='CDM Hydro', color='r')
ax0.plot(bins_2cdm_2,dk_2cdm_2, '--',label='2cDM Hydro', color='b')
ax0.set_xlabel('k (h/Mpc)')
ax0.set_ylabel('$P(k)$')
ax0.set_xscale('log')
ax0.set_yscale('log')

ax0.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax0.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax0.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax0.set_xlim(0, 10**3)
#ax.set_ylim(10**0, 10**5 + 20**4)

sax0 = ax0.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax0.set_xlabel('$\lambda$ (Mpc/h)')

ax0.set_title('DM Dimensionless Power Spectrum $512^{3}$ Particles')
ax0.grid(True, which="both", ls="-")
ax0.legend()

ax1.plot(bins_2cdm_1 ,pk_2cdm_1 / pk_cdm_1, color='b', label='Hydro')
ax1.plot(bins_2cdm_2 ,pk_2cdm_2 / pk_cdm_2, color='k', label='DM')
#ax1.set_xlabel('k (h/Mpc)')
ax1.set_ylabel('$P_{2cDM}/P_{CDM}$')
ax1.set_xscale('log')
#ax.set_yscale('log')

#ax1.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
#ax1.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
#ax1.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax1.set_xlim(0, 10**3)
ax1.set_ylim(0, 1.3)

sax1 = ax1.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
#sax1.set_xlabel('$\lambda$ (Mpc/h)')

#ax0.set_title('DM Dimensionless Power Spectrum z = {}'.format(Redshift_CDM_2))
ax1.grid(True, which="both", ls="-")
ax1.legend()

fname = 'DM_Spectrum_with_Ratio_512.png'
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=[24,18], gridspec_kw={'height_ratios': [3, 1]})
ax0.plot(lbins_cdm_1,ldk_cdm_1, label='CDM DM', color='g')
ax0.plot(lbins_2cdm_1,ldk_2cdm_1, '--',label='2cDM DM', color='k')
ax0.plot(lbins_cdm_2,ldk_cdm_2, label='CDM Hydro', color='r')
ax0.plot(lbins_2cdm_2,ldk_2cdm_2, '--',label='2cDM Hydro', color='b')
ax0.set_xlabel('k (h/Mpc)')
ax0.set_ylabel('$P(k)$')
ax0.set_xscale('log')
ax0.set_yscale('log')

ax0.plot([],[], label='z = {}'.format(Redshift_CDM_1), alpha=0)
ax0.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax0.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax0.set_xlim(0, 10**3)
#ax.set_ylim(10**0, 10**5 + 20**4)

sax0 = ax0.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax0.set_xlabel('$\lambda$ (Mpc/h)')

ax0.set_title('DM Dimensionless Power Spectrum $128^{3}$ Particles')
ax0.grid(True, which="both", ls="-")
ax0.legend()

ax1.plot(lbins_2cdm_1 ,lpk_2cdm_1 / lpk_cdm_1, color='b', label='Hydro')
ax1.plot(lbins_2cdm_2 ,lpk_2cdm_2 / lpk_cdm_2, color='k', label='DM')
#ax1.set_xlabel('k (h/Mpc)')
ax1.set_ylabel('$P_{2cDM}/P_{CDM}$')
ax1.set_xscale('log')
#ax.set_yscale('log')

#ax1.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
#ax1.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
#ax1.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax1.set_xlim(0, 10**3)
ax1.set_ylim(0, 1.3)

sax1 = ax1.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
#sax1.set_xlabel('$\lambda$ (Mpc/h)')

#ax0.set_title('DM Dimensionless Power Spectrum z = {}'.format(Redshift_CDM_2))
ax1.grid(True, which="both", ls="-")
ax1.legend()

fname = 'DM_Spectrum_with_Ratio_128.png'
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(figsize=[12,12])
ax.plot(bins_2cdm_1 ,pk_2cdm_1 / pk_cdm_1, color='k', label='Hydro')
ax.plot(bins_2cdm_2 ,pk_2cdm_2 / pk_cdm_2, color='b', label='DM')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$P_{2cDM}/P_{CDM}$')
ax.set_xscale('log')
#ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)
ax.set_ylim(0, 1.3)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('Ratio of DM Power Spectra z = {}'.format(Redshift_CDM_2))
plt.legend()
plt.grid(True, which="both", ls="-")
fname = 'DM_Spectrum_Ratio_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   del sys.path[0]
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(figsize=[12,12])
ax.plot(bins_cdm_1,dk_cdm_1, label='CDM DM', color='g')
ax.plot(bins_2cdm_1,dk_2cdm_1, '--',label='2cDM DM', color='k')
ax.plot(bins_cdm_2,dk_cdm_2, label='CDM Hydro', color='r')
ax.plot(bins_2cdm_2,dk_2cdm_2, '--',label='2cDM Hydro', color='b')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$P(k)$')
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)
#ax.set_ylim(10**0, 10**5 + 20**4)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('DM Dimensionless Power Spectrum z = {}'.format(Redshift_CDM_2))
plt.grid(True, which="both", ls="-")
plt.legend()
fname = 'DM_Dimless_Spectrum_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
# get by data for both

cdm_str = 'PK-by-snap_00{}_CDM.hdf5'
tcdm_str = 'PK-by-snap_00{}_2cDM.hdf5'

#bins_cdm_1, pk_cdm_1, dk_cdm_1 = get_genPK_data(pkpath_1 + cdm_str.format(CDM_i_1),\
#                                              k_conv_1, p_conv_1)
#bins_2cdm_1, pk_2cdm_1, dk_2cdm_1 = get_genPK_data(pkpath_1 + tcdm_str.format(tcDM_i_1),\
#                                                k_conv_1, p_conv_1)
bins_cdm_2, pk_cdm_2, dk_cdm_2 = get_genPK_data(pkpath_2 + cdm_str.format(CDM_i_2),\
                                                k_conv_2, p_conv_2)
bins_2cdm_2, pk_2cdm_2, dk_2cdm_2 = get_genPK_data(pkpath_2 + tcdm_str.format(tcDM_i_2),\
                                                k_conv_2, p_conv_2)

# %%
fig, ax = plt.subplots(figsize=[12,12])
#ax.plot(bins_cdm_1,pk_cdm_1, label='CDM L3N512', color='g')
#ax.plot(bins_2cdm_1,pk_2cdm_1, '--',label='2cDM L3N512', color='k')
ax.plot(bins_cdm_2,pk_cdm_2, label='CDM', color='r')
ax.plot(bins_2cdm_2,pk_2cdm_2, '--',label='2cDM', color='b')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$P(k)$')
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('Baryon Power Spectrum z = {}'.format(Redshift_CDM_2))
plt.legend()
plt.grid(True, which="both", ls="-")
fname = 'BY_Power_Spectrum_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(figsize=[12,12])
#ax.plot(bins_2cdm_1 ,pk_2cdm_1 / pk_cdm_1, color='k', label='L3N512')
ax.plot(bins_2cdm_2 ,pk_2cdm_2 / pk_cdm_2, color='b', label='Hydro')
#ax.plot(bins_2cdm_2, pk_2cdm_2 / pk_cdm_1, color='b', label='small IC')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$P_{2cDM}/P_{CDM}$')
ax.set_xscale('log')
#ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)
ax.set_ylim(0, 1.3)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('Ratio of Baryon Power Spectra z = {}'.format(Redshift_CDM_2))
plt.legend()
plt.grid(True, which="both", ls="-")
fname = 'BY_Spectrum_Ratio_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(figsize=[12,12])
#ax.plot(bins_cdm_1,dk_cdm_1, label='CDM L3N512', color='g')
#ax.plot(bins_2cdm_1,dk_2cdm_1, '--',label='2cDM L3N512', color='k')
ax.plot(bins_cdm_2,dk_cdm_2, label='CDM', color='r')
ax.plot(bins_2cdm_2,dk_2cdm_2, '--',label='2cDM', color='b')
ax.set_xlabel('k (h/Mpc)')
ax.set_ylabel('$\Delta^{2}(k)$')
ax.set_xscale('log')
ax.set_yscale('log')

ax.plot([],[], label='z = {}'.format(Redshift_CDM_2), alpha=0)
ax.plot([],[], label='(0, 0) $\sigma = 1$', alpha=0)
ax.plot([],[], label='$\Delta m/m$ = 5.56e-8', alpha=0)

ax.set_xlim(0, 10**3)
#ax.set_ylim(10**0, 10**5 + 20**4)

sax = ax.secondary_xaxis('top', functions=(wnumber2wlength, wlength2wnumber))
sax.set_xlabel('$\lambda$ (Mpc/h)')
plt.title('Baryon Dimensionless Power Spectrum z = {}'.format(Redshift_CDM_2))
plt.grid(True, which="both", ls="-")
plt.legend()
fname = 'BY_Dimless_Spectrum_L{}_z={}.png'.format(Boxsize_2, Redshift_CDM_2)
plt.savefig(fpath+fname, dpi=150)
plt.show()
# Out:
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/ryan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
